# %%
import numpy as np
import pandas as pd

df = pd.read_csv("NSE-TATAGLOBAL.csv")
df
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-09-28  234.05  235.95  230.20  233.50  233.75
# 1     2018-09-27  234.55  236.80  231.10  233.80  233.25
# 2     2018-09-26  240.00  240.00  232.50  235.00  234.25
# 3     2018-09-25  233.30  236.75  232.00  236.25  236.10
# 4     2018-09-24  233.55  239.20  230.75  234.00  233.30
# ...          ...     ...     ...     ...     ...     ...
# 2030  2010-07-27  117.60  119.50  112.00  118.80  118.65
# 2031  2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2032  2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2033  2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2034  2010-07-21  122.10  123.00  121.05  121.10  121.55
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                  3069914          7162.35
# 1                  5082859         11859.95
# 2                  2240909          5248.60
# 3                  2349368          5503.90
# 4                  3423509          7999.55
# ...                    ...              ...
# 2030                586100           694.98
# 2031                658440           780.01
# 2032                281312           340.31
# 2033                293312           355.17
# 2034                658666           803.56
#
# [2035 rows x 8 columns]

# %%
df = df[::-1]
df
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-09-28  234.05  235.95  230.20  233.50  233.75
# 1     2018-09-27  234.55  236.80  231.10  233.80  233.25
# 2     2018-09-26  240.00  240.00  232.50  235.00  234.25
# 3     2018-09-25  233.30  236.75  232.00  236.25  236.10
# 4     2018-09-24  233.55  239.20  230.75  234.00  233.30
# ...          ...     ...     ...     ...     ...     ...
# 2030  2010-07-27  117.60  119.50  112.00  118.80  118.65
# 2031  2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2032  2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2033  2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2034  2010-07-21  122.10  123.00  121.05  121.10  121.55
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                  3069914          7162.35
# 1                  5082859         11859.95
# 2                  2240909          5248.60
# 3                  2349368          5503.90
# 4                  3423509          7999.55
# ...                    ...              ...
# 2030                586100           694.98
# 2031                658440           780.01
# 2032                281312           340.31
# 2033                293312           355.17
# 2034                658666           803.56
#
# [2035 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 143.1+ KB

# %%
df.describe()
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %%
df.drop_duplicates(inplace = True)
df
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-09-28  234.05  235.95  230.20  233.50  233.75
# 1     2018-09-27  234.55  236.80  231.10  233.80  233.25
# 2     2018-09-26  240.00  240.00  232.50  235.00  234.25
# 3     2018-09-25  233.30  236.75  232.00  236.25  236.10
# 4     2018-09-24  233.55  239.20  230.75  234.00  233.30
# ...          ...     ...     ...     ...     ...     ...
# 2030  2010-07-27  117.60  119.50  112.00  118.80  118.65
# 2031  2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2032  2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2033  2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2034  2010-07-21  122.10  123.00  121.05  121.10  121.55
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                  3069914          7162.35
# 1                  5082859         11859.95
# 2                  2240909          5248.60
# 3                  2349368          5503.90
# 4                  3423509          7999.55
# ...                    ...              ...
# 2030                586100           694.98
# 2031                658440           780.01
# 2032                281312           340.31
# 2033                293312           355.17
# 2034                658666           803.56
#
# [2035 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(df.corr(),annot = True)
plt.show()
# Out:
# <ipython-input-51-d818cb4a57f8>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot = True)

# %%
df_high = df.reset_index()['High']
df_high
# Out:
# 0       235.95
# 1       236.80
# 2       240.00
# 3       236.75
# 4       239.20
#          ...
# 2030    119.50
# 2031    121.00
# 2032    121.95
# 2033    122.00
# 2034    123.00
# Name: High, Length: 2035, dtype: float64

# %%
plt.plot(df_high)
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

MMS = MinMaxScaler()
df_high = MMS.fit_transform(df_high.values.reshape(-1,1))
df_high
# Out:
# array([[0.62268754],
#        [0.62614353],
#        [0.6391543 ],
#        ...,
#        [0.15917869],
#        [0.15938199],
#        [0.16344786]])

# %%
train_size = int(len(df_high) * 0.8)
test_size = len(df_high) - train_size

train_size, test_size
# Out:
# (1628, 407)

# %%
train_data, test_data = df_high[:train_size, :], df_high[train_size:, :1]
train_data.shape
# Out:
# (1628, 1)

# %%
def create_data(data,time_step):
  X_data, Y_data = [], []

  for i in range(len(data)- time_step - 1):
    prev = data[i: i+time_step, 0]
    X_data.append(prev)
    Y_data.append(data[i+time_step, 0])

  return np.array(X_data), np.array(Y_data)

# %%
time_step = 100
X_train, Y_train = create_data(train_data, time_step)
X_test, Y_test = create_data(test_data, time_step)

# %%
X_train =  X_train.reshape(X_train.shape[0],X_train.shape[1], 1)
X_test =  X_test.reshape(X_test.shape[0],X_test.shape[1], 1)
X_train.shape ,Y_train.shape
# Out:
# ((1527, 100, 1), (1527,))

# %%
import tensorflow as tf

from tensorflow.python.keras.models import Sequential

from tensorflow.python.keras.layers import Dense, LSTM

model = Sequential()

model.add(LSTM(50, return_sequences = True, input_shape = (100, 1))) 
model.add(LSTM(50, return_sequences = True))

model.add(LSTM(50))

model.add(Dense (1))

model.compile(loss = 'mean_squared_error', optimizer = 'adam')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 100, 50)           10400
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, Y_train, validation_data = (X_test, Y_test), epochs = 10, batch_size = 64,verbose=True)
# Out:
# Epoch 1/10
# 24/24 [==============================] - 13s 517ms/step - loss: 3.8637e-04 - val_loss: 0.0093
# Epoch 2/10
# 24/24 [==============================] - 10s 429ms/step - loss: 3.7661e-04 - val_loss: 0.0059
# Epoch 3/10
# 24/24 [==============================] - 10s 406ms/step - loss: 3.9713e-04 - val_loss: 0.0071
# Epoch 4/10
# 24/24 [==============================] - 11s 459ms/step - loss: 3.4371e-04 - val_loss: 0.0068
# Epoch 5/10
# 24/24 [==============================] - 11s 447ms/step - loss: 3.2854e-04 - val_loss: 0.0070
# Epoch 6/10
# 24/24 [==============================] - 11s 453ms/step - loss: 3.2349e-04 - val_loss: 0.0093
# Epoch 7/10
# 24/24 [==============================] - 11s 447ms/step - loss: 3.7174e-04 - val_loss: 0.0106
# Epoch 8/10
# 24/24 [==============================] - 10s 413ms/step - loss: 3.4183e-04 - val_loss: 0.0059
# Epoch 9/10
# 24/24 [==============================] - 10s 413ms/step - loss: 3.0869e-04 - val_loss: 0.0065
# Epoch 10/10
# 24/24 [==============================] - 11s 450ms/step - loss: 3.0750e-04 - val_loss: 0.0080

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# %%
from math import sqrt

from sklearn.metrics import mean_squared_error

rmse_train = sqrt (mean_squared_error(Y_train, train_predict)) 
rmse_test = sqrt (mean_squared_error(Y_test, test_predict)) 
rmse_train, rmse_test
# Out:
# (0.017455719713577022, 0.08955337747767798)

# %%
train_predict = MMS. inverse_transform(train_predict) 
test_predict = MMS.inverse_transform(test_predict)

# %%
look_back = 10
trainpredictPlot = np.empty_like(df_high)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back: len(train_predict) + look_back, :]= train_predict

testPredictPlot = np.empty_like(df_high)
testPredictPlot[:,:]= np.nan
testPredictPlot[len (train_predict)+(look_back * 2)+1: len(df_high) -1, :] = test_predict

# %%
plt.plot (MMS. inverse_transform(df_high))

plt.plot(trainPredictPlot) 
plt.plot(testPredictPlot)

plt.legend (labels = ['Complete data', 'Train data', 'Predicted data'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-bc74544e3093> in <cell line: 3>()
#       1 plt.plot (MMS. inverse_transform(df_high))
#       2
# ----> 3 plt.plot(trainPredictPlot)
#       4 plt.plot(testPredictPlot)
#       5
#
# NameError: name 'trainPredictPlot' is not defined
